# %% [markdown]
# <a href="https://colab.research.google.com/github/fatenmegahed/npro/blob/main/students_performance_accuracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv(r'/content/student_mat.csv')
df2=pd.read_csv(r'/content/student_por.csv')
df=pd.concat([df1,df2])

# %%
df.head()
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 644       1    0   19        0        0        1     2     3     3     2  ...
# 645       1    0   18        1        1        1     3     1     4     3  ...
# 646       1    0   18        1        0        1     1     1     2     2  ...
# 647       1    1   17        1        1        1     3     1     3     3  ...
# 648       1    1   18        0        1        1     3     2     3     2  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1044 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %%
num_cols=df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
cat_cols=df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
fjob_count=df['Fjob'].value_counts()
fjob_count
# Out:
# Fjob
# other       584
# services    292
# teacher      65
# at_home      62
# health       41
# Name: count, dtype: int64

# %%
plt.hist(df['Fjob'],color=['blue'])
plt.xlabel('Fjob')
plt.ylabel('Frequency')
plt.title('Fjob Distribution')
# Out:
# Text(0.5, 1.0, 'Fjob Distribution')

# %%
plt.scatter(df['absences'],df['G3'])
plt.plot()
plt.xlabel('absences')
plt.ylabel('Final Grade')
plt.title('absences vs Final Grade')
# Out:
# Text(0.5, 1.0, 'absences vs Final Grade')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in cat_cols:
  df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
plt.hist(df['G3'],color='blue')
plt.xlabel('Final Grade')
# Out:
# Text(0.5, 0, 'Final Grade')

# %%
plt.hist(df['age'],color='blue')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
plt.pie(df['sex'].value_counts(),labels=['female','male'],autopct='%1.1f%%')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
plt.pie(df['school'].value_counts(),labels=['GP','MS'],autopct='%1.1f%%')
plt.title('School Distribution')
# Out:
# Text(0.5, 1.0, 'School Distribution')

# %%
from sklearn.model_selection import train_test_split
x=df.drop('G3',axis=1)
y=df['G3']

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
#predicition=lr.predict(x_test)
#print(predicition)
acc_lr=lr.score(x_test,y_test)
acc_lr
# Out:
# 0.7961687973654601

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
acc_rf=rf.score(x_test,y_test)
acc_rf
# Out:
# 0.7976477086136843

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
acc_dt=dt.score(x_test,y_test)
#print(acc_dt)
acc_dt
# Out:
# 0.6493683219218651

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(x_train,y_train)
acc_sv=sv.score(x_test,y_test)
acc_sv
# Out:
# 0.7029816460267637

# %%
Model=['Linear Regression','Random Forest','Decision Tree','Support Vector Machine']
Accuracy=[0.796,0.794,0.668,0.7020]
plt.figure(figsize=(8,8), )
plt.bar(Model,Accuracy,color='blue')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.xticks(rotation=45)
# Out:
# /tmp/ipython-input-1861643992.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Linear Regression'),
#   Text(1, 0, 'Random Forest'),
#   Text(2, 0, 'Decision Tree'),
#   Text(3, 0, 'Support Vector Machine')])
